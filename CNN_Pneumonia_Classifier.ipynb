# %% [markdown]
# <a href="https://colab.research.google.com/github/aramirezfr/RecommenderSystemProject/blob/master/CNN_Pneumonia_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pneumonia Image Binary Classifier Model** \
# By: Adriana Ramirez Franco. \
# Email: aramirezfr20@gmail.com \
# Github: @aramirezfr

# %% [markdown]
# # Business Understanding

# %% [markdown]
# **About Pneumonia:** \
# Pneumonia is a serious respiratory condition that can lead to severe complications, especially if not diagnosed early. Timely and accurate diagnosis is crucial to initiate appropriate treatment and reduce morbidity and mortality, particularly among vulnerable populations like children, the elderly, and individuals with compromised immune systems.

# %% [markdown]
# **Why not using traditional in person diagnosis by doctors?** \
# Traditional diagnosis of pneumonia relies heavily on radiologists interpreting chest X-rays, which can be time-consuming and prone to human error, especially under high workloads or in resource-limited settings.

# %% [markdown]
# **How can we support a professional doctor's diagnosis?** \
# To address these challenges, this project aims to develop a convolutional neural network (CNN)-based binary classification model to automatically identify pneumonia from chest X-ray images. By distinguishing between normal and pneumonia-affected lungs, the model will assist healthcare professionals in making quicker, more accurate decisions. This model can improve diagnostic efficiency, alleviate the burden on radiologists, enhance patient outcomes, and provide valuable support in remote or underserved areas where access to specialized radiology expertise is limited.

# %% [markdown]
# ## Benefits of implementing a Medical Image Classifier

# %% [markdown]
# **Medical image classification using machine learning** is critically important for several reasons:
#
# ### **1. Faster Diagnosis and Treatment**
# Convolutional neural networks (CNNs), can analyze medical images much faster than humans. This reduces the time required for diagnosis, enabling quicker initiation of treatment, which is particularly crucial for conditions like pneumonia, cancer, or strokes where delays can have life-threatening consequences.
#
# ### **2. Improved Accuracy and Consistency**
# Machine learning systems can match or exceed the diagnostic accuracy of radiologists in specific tasks, as they learn from large datasets and can identify patterns that may be difficult for human experts to detect. This ensures consistency in diagnosis, reducing human errors caused by fatigue or cognitive bias.
#
# ### **3. Addressing Resource Gaps**
# In many regions, especially remote or low-resource settings, there is a shortage of radiologists and specialized healthcare professionals. Machine learning models can act as decision-support tools to help non-specialists make informed diagnoses or prioritize cases that need expert attention.
#
# ### **4. Reduced Workload for Healthcare Professionals**
# With the increasing demand for medical imaging, radiologists often have to analyze hundreds of images per day. AI systems can help pre-screen images or highlight abnormal cases, allowing radiologists to focus their expertise on the most critical cases, improving workflow efficiency.
#
# ### **5. Continuous Learning and Scalability**
# Machine learning models can continuously improve as they are trained with new data, making them adaptable to emerging medical conditions. They are also scalable, meaning once a model is developed, it can be deployed across multiple healthcare systems globally with minimal modifications.
#
# ### **6. Enabling Preventive Healthcare**
# Automated image classification can also aid in early detection of diseases that may not exhibit symptoms initially, facilitating preventive interventions. For instance, AI models used for early screening of pneumonia or lung cancer can detect subtle abnormalities that might be missed in routine examinations.
#
# In summary, machine learning-based medical image classification is transforming healthcare by enhancing diagnostic accuracy, improving efficiency, and expanding access to quality care, making it an essential tool for modern medicine.

# %% [markdown]
# # Data Understanding

# %% [markdown]
# 1. **Source and Properties of the Data**:
#    - This dataset, published by Paul Mooney on Kaggle, originates from the Guangzhou Women and Children’s Medical Center. It contains labeled chest X-ray images grouped into "Pneumonia" (with bacterial and viral categories) and "Normal."
#    - The images are grayscale with consistent resolution, showing clear lung structures. The dataset is ideal for supervised machine learning tasks since each image is accurately labeled as pneumonia or healthy, making it a reliable choice for binary classification.

# %% [markdown]
# 2. **Size of Data and Descriptive Statistics of Features**:
#    - The dataset comprises 5,863 images, divided into training, validation, and test sets, enabling efficient model evaluation. The training set includes around 4,000 images, with a smaller validation and test set.
#    - Key features include image pixel intensity values, which represent lung opacity patterns. The dataset contains approximately three times more pneumonia cases than normal ones, making it slightly imbalanced.

# %% [markdown]
# 3. **Feature Suitability**:
#    The primary feature—chest X-ray images—allows for visual detection of pneumonia markers, such as lung opacity and structure irregularities. This aligns well with the objective to classify cases of pneumonia versus healthy lungs based on these medical imaging patterns.

# %% [markdown]
# 4. **Limitations of Using This Data**:
#    - *Challenges*: The dataset's class imbalance (more pneumonia cases than normal) could affect model performance. The variation in image quality and possible label inconsistencies may also introduce noise, impacting model accuracy and generalizability.
#    - *Generalization Limits*: Since the dataset was sourced from a specific medical center, models trained on it might not generalize well to X-rays from different machines or patient demographics.

# %% [markdown]
# For further details, refer to the Kaggle dataset page: [Chest X-Ray Images (Pneumonia) on Kaggle](https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia).

# %% [markdown]
# # Data Preparation

# %% [markdown]
# I will begin downloading the necessary file from Kaggle, unzip the file, and I will be importing the necessary libraries for this project.

# %%
#Downloading the data file from Kaggle
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# Dataset URL: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# License(s): other
# Downloading chest-xray-pneumonia.zip to /content
# 100% 2.29G/2.29G [00:33<00:00, 110MB/s]
# 100% 2.29G/2.29G [00:33<00:00, 73.4MB/s]

# %%
#Unzip the data folder
# !unzip chest-xray-pneumonia.zip -d data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/chest_xray/train/NORMAL/IM-0435-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0435-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0437-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0437-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0437-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0438-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0439-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0439-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0439-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0440-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0441-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0442-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0444-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0445-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0446-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0447-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0448-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0449-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0450-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0451-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0452-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0453-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0453-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0455-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0456-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0457-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0458-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0459-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0460-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0461-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0463-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0464-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0465-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0466-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0467-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0467-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0467-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0469-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0471-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0472-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0473-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0474-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0475-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0476-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0477-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0478-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0479-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0480-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0481-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0482-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0483-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0484-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0485-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0486-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0487-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0488-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0489-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0490-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0491-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0491-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0491-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0492-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0493-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0494-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0495-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0496-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0497-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0497-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0497-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0499-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0499-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0499-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0500-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0501-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0501-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0501-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0502-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0503-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0504-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0505-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0505-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0505-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0506-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0507-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0508-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0509-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0509-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0509-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0510-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0511-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0511-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0511-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0512-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0513-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0514-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0515-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0516-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0517-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0517-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0519-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0519-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0519-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0520-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0521-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0522-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0523-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0523-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0523-0001-0003.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0523-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0524-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0525-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0525-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0525-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0526-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0527-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0528-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0529-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0530-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0531-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0531-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0532-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0533-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0533-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0533-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0534-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0535-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0536-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0537-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0538-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0539-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0539-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0539-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0540-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0541-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0542-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0543-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0543-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0544-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0545-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0545-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0545-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0546-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0547-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0548-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0549-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0549-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0549-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0551-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0551-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0551-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0552-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0553-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0553-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0553-0001-0003.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0553-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0554-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0555-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0555-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0555-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0556-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0557-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0559-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0560-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0561-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0562-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0563-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0564-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0565-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0566-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0568-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0569-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0570-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0571-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0574-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0575-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0577-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0578-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0579-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0580-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0581-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0582-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0583-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0584-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0586-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0588-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0590-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0591-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0592-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0593-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0595-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0596-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0598-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0599-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0600-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0601-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0602-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0604-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0605-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0606-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0607-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0608-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0608-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0608-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0609-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0612-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0612-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0612-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0613-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0614-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0615-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0616-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0617-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0618-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0618-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0618-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0619-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0620-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0620-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0620-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0621-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0622-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0622-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0622-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0623-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0624-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0624-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0625-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0626-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0626-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0627-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0628-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0629-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0629-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0629-0001-0003.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0629-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0630-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0631-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0631-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0631-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0632-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0633-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0634-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0635-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0636-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0637-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0640-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0640-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0640-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0641-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0642-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0643-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0644-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0644-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0644-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0645-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0646-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0647-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0648-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0649-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0650-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0650-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0650-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0651-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0652-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0652-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0654-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0655-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0656-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0656-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0656-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0657-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0658-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0659-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0660-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0660-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0660-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0661-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0662-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0663-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0664-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0665-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0666-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0666-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0666-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0667-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0668-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0669-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0670-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0671-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0672-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0673-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0674-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0675-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0676-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0677-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0678-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0679-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0680-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0681-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0682-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0683-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0684-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0685-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0686-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0687-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0688-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0689-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0691-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0692-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0693-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0694-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0695-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0696-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0697-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0698-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0700-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0701-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0702-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0703-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0704-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0705-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0706-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0707-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0709-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0710-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0711-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0712-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0713-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0714-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0715-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0716-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0717-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0718-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0719-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0721-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0722-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0724-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0727-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0728-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0729-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0730-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0732-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0733-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0734-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0735-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0736-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0737-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0738-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0739-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0740-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0741-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0742-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0746-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0747-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0748-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0750-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0751-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0752-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0753-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0754-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0755-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0757-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0761-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0764-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/IM-0766-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0383-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0384-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0385-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0386-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0388-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0389-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0390-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0391-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0392-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0393-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0394-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0396-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0397-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0399-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0401-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0402-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0403-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0404-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0406-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0407-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0408-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0409-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0410-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0412-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0413-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0414-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0415-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0416-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0416-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0416-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0417-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0418-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0419-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0421-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0423-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0424-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0425-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0427-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0428-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0429-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0433-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0435-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0437-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0439-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0440-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0441-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0443-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0445-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0447-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0448-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0449-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0450-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0451-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0452-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0453-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0454-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0455-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0456-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0458-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0460-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0462-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0463-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0464-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0465-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0466-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0468-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0472-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0473-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0474-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0475-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0476-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0478-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0479-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0480-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0481-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0482-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0485-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0486-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0487-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0488-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0489-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0490-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0491-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0493-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0496-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0497-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0499-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0500-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0501-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0502-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0503-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0506-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0507-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0508-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0509-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0511-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0512-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0513-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0515-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0516-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0517-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0518-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0520-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0521-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0522-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0523-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0525-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0526-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0528-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0529-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0530-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0531-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0533-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0535-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0535-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0536-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0537-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0539-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0540-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0541-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0543-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0545-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0547-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0550-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0551-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0552-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0553-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0554-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0555-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0555-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0555-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0557-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0558-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0559-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0561-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0563-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0564-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0566-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0567-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0568-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0569-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0571-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0572-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0573-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0575-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0576-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0577-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0578-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0579-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0580-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0582-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0583-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0585-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0588-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0589-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0592-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0594-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0595-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0596-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0599-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0600-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0601-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0602-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0603-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0604-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0609-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0611-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0616-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0617-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0618-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0619-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0620-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0621-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0622-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0623-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0626-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0627-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0629-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0630-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0633-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0634-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0635-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0636-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0637-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0640-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0641-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0642-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0643-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0645-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0647-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0648-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0649-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0650-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0651-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0651-0004.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0652-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0653-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0654-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0655-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0657-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0659-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0660-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0661-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0662-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0663-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0664-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0665-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0666-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0667-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0668-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0669-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0671-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0672-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0673-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0675-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0678-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0680-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0682-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0683-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0684-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0686-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0687-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0689-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0690-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0692-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0693-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0694-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0695-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0696-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0698-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0699-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0700-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0702-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0705-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0707-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0718-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0719-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0723-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0725-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0727-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0730-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0736-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0741-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0744-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0746-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0749-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0753-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0757-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0765-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0771-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0772-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0774-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0775-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0776-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0777-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0780-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0781-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0790-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0793-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0796-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0797-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0798-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0799-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0803-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0804-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0806-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0807-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0808-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0809-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0810-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0811-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0812-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0814-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0815-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0816-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0818-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0818-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0819-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0820-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0821-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0822-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0824-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0825-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0826-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0827-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0828-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0829-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0830-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0831-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0833-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0834-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0836-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0837-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0838-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0839-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0840-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0841-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0842-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0843-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0845-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0846-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0847-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0848-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0849-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0851-0001-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0851-0001-0002.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0851-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0852-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0853-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0854-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0855-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0856-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0857-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0858-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0859-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0860-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0862-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0863-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0865-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0866-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0867-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0868-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0869-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0870-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0871-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0872-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0873-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0874-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0875-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0876-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0877-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0879-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0880-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0881-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0882-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0885-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0886-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0887-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0888-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0890-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0892-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0893-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0894-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0895-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0896-0001.jpeg
#   inflating: data/chest_xray/train/NORMAL/NORMAL2-IM-0897-0001.jpeg
# ...
#   inflating: data/chest_xray/train/PNEUMONIA/person890_bacteria_2814.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person890_virus_1540.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person891_virus_1541.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person892_bacteria_2817.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person893_bacteria_2818.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person894_bacteria_2819.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person894_virus_1546.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person895_bacteria_2820.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person895_virus_1547.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person896_bacteria_2821.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person896_virus_1548.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person897_bacteria_2822.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person898_bacteria_2823.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person898_virus_1552.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person899_virus_1553.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person89_virus_168.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person8_bacteria_37.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person900_virus_1554.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person901_virus_1555.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person902_bacteria_2827.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person903_bacteria_2828.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person904_bacteria_2829.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person905_bacteria_2830.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person905_virus_1561.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person906_bacteria_2831.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person906_virus_1562.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person907_bacteria_2832.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person907_virus_1563.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person908_virus_1564.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person909_bacteria_2834.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person909_virus_1565.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person90_virus_169.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person90_virus_170.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person911_bacteria_2836.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person911_virus_1567.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person912_bacteria_2837.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person913_bacteria_2838.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person913_virus_1570.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person914_bacteria_2839.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person914_virus_1571.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person915_virus_1572.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person916_bacteria_2841.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person917_bacteria_2842.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person918_bacteria_2843.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person918_virus_1575.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person919_bacteria_2844.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person919_virus_1576.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person920_bacteria_2845.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person920_virus_1577.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person921_bacteria_2846.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person921_virus_1578.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person922_bacteria_2847.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person923_bacteria_2848.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person924_bacteria_2849.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person924_virus_1581.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person925_bacteria_2850.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person925_virus_1582.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person926_virus_1583.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person927_bacteria_2852.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person927_virus_1584.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person928_virus_1586.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person929_bacteria_2854.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person929_virus_1588.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person929_virus_1589.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person92_virus_174.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person930_bacteria_2855.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person931_bacteria_2856.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person931_virus_1592.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person932_virus_1593.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person933_bacteria_2858.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person933_virus_1594.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person934_bacteria_2859.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person934_virus_1595.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person935_virus_1597.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person936_bacteria_2861.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person936_virus_1598.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person937_bacteria_2862.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person937_virus_1599.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person938_bacteria_2863.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person938_virus_1600.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person939_bacteria_2864.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person93_virus_175.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person940_bacteria_2865.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person940_virus_1602.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person940_virus_1604.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person940_virus_1605.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person940_virus_1607.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person940_virus_1609.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person941_virus_1610.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person942_bacteria_2867.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person942_virus_1611.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person943_bacteria_2868.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person944_bacteria_2869.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person945_bacteria_2870.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person945_virus_1616.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person946_bacteria_2871.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person947_bacteria_2872.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person947_virus_1618.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person949_bacteria_2874.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person949_virus_1620.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person94_virus_176.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person950_virus_1621.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person951_bacteria_2876.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person951_virus_1622.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person952_bacteria_2877.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person952_virus_1623.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person953_bacteria_2878.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person954_bacteria_2879.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person954_virus_1626.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person955_bacteria_2880.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person955_virus_1627.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person956_bacteria_2881.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person956_virus_1628.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person957_bacteria_2882.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person957_virus_1629.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person958_bacteria_2883.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person958_virus_1630.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person959_bacteria_2884.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person95_virus_177.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person960_bacteria_2885.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person960_virus_1633.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person961_bacteria_2886.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person961_virus_1634.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person962_bacteria_2887.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person962_virus_1635.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person963_bacteria_2888.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person963_virus_1636.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person964_bacteria_2889.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person964_virus_1637.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person965_bacteria_2890.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person965_virus_1638.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person966_bacteria_2891.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person966_virus_1639.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person967_bacteria_2892.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person967_virus_1640.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person968_bacteria_2893.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person968_virus_1642.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person969_bacteria_2894.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person969_virus_1643.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person96_virus_178.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person96_virus_179.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person970_bacteria_2895.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person970_virus_1644.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person971_bacteria_2896.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person972_bacteria_2897.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person972_virus_1646.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person973_virus_1647.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person974_bacteria_2899.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person974_virus_1649.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person975_virus_1650.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person976_bacteria_2901.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person976_virus_1651.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person977_bacteria_2902.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person977_virus_1652.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person978_bacteria_2904.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person978_virus_1653.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person979_bacteria_2905.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person979_virus_1654.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person97_virus_180.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person97_virus_181.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person980_bacteria_2906.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person980_virus_1655.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person981_bacteria_2907.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person981_bacteria_2908.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person981_virus_1657.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person982_bacteria_2909.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person982_virus_1658.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person983_bacteria_2910.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person983_virus_1660.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person984_bacteria_2911.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person985_bacteria_2912.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person986_bacteria_2913.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person987_bacteria_2914.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person988_bacteria_2915.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person988_virus_1666.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person989_virus_1667.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person98_virus_182.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person990_bacteria_2917.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person991_bacteria_2918.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person991_virus_1669.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person992_bacteria_2919.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person992_bacteria_2920.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person992_virus_1670.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person993_bacteria_2921.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person993_virus_1671.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person994_bacteria_2922.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person994_virus_1672.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person995_bacteria_2923.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person995_virus_1676.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person996_bacteria_2924.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person996_virus_1677.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person997_bacteria_2926.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person997_virus_1678.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person998_bacteria_2927.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person998_bacteria_2928.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person99_virus_183.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person9_bacteria_38.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person9_bacteria_39.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person9_bacteria_40.jpeg
#   inflating: data/chest_xray/train/PNEUMONIA/person9_bacteria_41.jpeg
#   inflating: data/chest_xray/val/NORMAL/NORMAL2-IM-1427-0001.jpeg
#   inflating: data/chest_xray/val/NORMAL/NORMAL2-IM-1430-0001.jpeg
#   inflating: data/chest_xray/val/NORMAL/NORMAL2-IM-1431-0001.jpeg
#   inflating: data/chest_xray/val/NORMAL/NORMAL2-IM-1436-0001.jpeg
#   inflating: data/chest_xray/val/NORMAL/NORMAL2-IM-1437-0001.jpeg
#   inflating: data/chest_xray/val/NORMAL/NORMAL2-IM-1438-0001.jpeg
#   inflating: data/chest_xray/val/NORMAL/NORMAL2-IM-1440-0001.jpeg
#   inflating: data/chest_xray/val/NORMAL/NORMAL2-IM-1442-0001.jpeg
#   inflating: data/chest_xray/val/PNEUMONIA/person1946_bacteria_4874.jpeg
#   inflating: data/chest_xray/val/PNEUMONIA/person1946_bacteria_4875.jpeg
#   inflating: data/chest_xray/val/PNEUMONIA/person1947_bacteria_4876.jpeg
#   inflating: data/chest_xray/val/PNEUMONIA/person1949_bacteria_4880.jpeg
#   inflating: data/chest_xray/val/PNEUMONIA/person1950_bacteria_4881.jpeg
#   inflating: data/chest_xray/val/PNEUMONIA/person1951_bacteria_4882.jpeg
#   inflating: data/chest_xray/val/PNEUMONIA/person1952_bacteria_4883.jpeg
#   inflating: data/chest_xray/val/PNEUMONIA/person1954_bacteria_4886.jpeg

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import math

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
from tensorflow.keras.utils import load_img, img_to_array
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.applications.resnet50 import preprocess_input
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau


import warnings
warnings.filterwarnings('ignore')

import os

# %% [markdown]
# -----------------

# %%
#setting the directory that contains the kaggle data file
directory=os.listdir('data/chest_xray')
print(directory) #listing contents of directory
# Out:
# ['val', 'train', '__MACOSX', 'test', 'chest_xray']

# %% [markdown]
# There are 3 directories inside the chest_xray file: training, validation and testing directory.

# %%
#setting the directories as variables
train_dir='data/chest_xray/train'
val_dir='data/chest_xray/val'
test_dir='data/chest_xray/test'

# %% [markdown]
# Using **image_dataset_from_directory** function to create a dataset from images stored in the previous directories.
# I will create 3 different datasets, one for each directory.

# %%
#creating datasets for all directories
train=keras.utils.image_dataset_from_directory(
    directory=train_dir,
    shuffle=True,
    labels='inferred',
    label_mode='binary',
    batch_size=32,
    image_size=(150, 150))

test = keras.utils.image_dataset_from_directory (
    directory = test_dir,
    shuffle=True,
    labels = "inferred",
    label_mode='binary',
    batch_size = 32,
    image_size = (150,150))
validation = keras.utils.image_dataset_from_directory (
    directory = val_dir,
    shuffle=True,
    labels ="inferred",
    label_mode='binary',
    batch_size = 32,
    image_size = (150 , 150))
# Out:
# Found 5216 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.
# Found 16 files belonging to 2 classes.

# %% [markdown]
# Each file in 'chest_xray' includes a set of images with **"Normal"** x-rays and another set of x-rays with **"Pneumonia"**.

# %%
#checking the name of the classes in the files
print(train.class_names)
print(test.class_names)
print(validation.class_names)
# Out:
# ['NORMAL', 'PNEUMONIA']
# ['NORMAL', 'PNEUMONIA']
# ['NORMAL', 'PNEUMONIA']

# %% [markdown]
# ------------------

# %% [markdown]
# **Setting up the Training data:**
#
# The model uses training data to learn patterns, relationships, and rules that map inputs to outputs. The quality and diversity of the training data significantly affect the model's ability to generalize. A model trained on imbalanced data can lead to poor performance in practical applications.
# We need to analyze if we have any imbalance.

# %%
#defining the directories of training images
pneumonia_dir = 'data/chest_xray/train/PNEUMONIA'
normal_dir = 'data/chest_xray/train/NORMAL'

#list files in each directory
pneumonia_files = os.listdir(pneumonia_dir)
normal_files = os.listdir(normal_dir)

#checking the quantity of images in each directory
len(pneumonia_files)+len(normal_files)
# Out:
# 5216

# %% [markdown]
# There are 5216 images to train on that belong to the subgroups **'PNEUMONIA'** and **'NORMAL'**.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# What is the visual difference between X-rays that show lungs with pneumonia and normal healthy lungs?

# %%
#plot the count of images
def display_images(image_files, image_dir, num_images=5, title=''):
    plt.figure(figsize=(8, 3))
    plt.suptitle(title, fontsize=14)

    for i, image_name in enumerate(image_files[:num_images]):
        image_path = os.path.join(image_dir, image_name)
        img = mpimg.imread(image_path)
        plt.subplot(1, num_images, i + 1)
        plt.imshow(img, cmap='gray')  #using 'gray' for grayscale images
        plt.title(image_name)
        plt.axis('off')

#display images from PNEUMONIA class
display_images(pneumonia_files, pneumonia_dir, num_images=3, title='PNEUMONIA')

#display images from NORMAL class
display_images(normal_files, normal_dir, num_images=3, title='NORMAL')

# %% [markdown]
# **DIFFERENCE OF LUNGS' X-RAYS WITH PNEUMONIA VS NORMAL:**
# - In X-ray images, healthy lungs appear clear with visible lung structures like the diaphragm, heart, and air-filled bronchial tubes. \
# -In contrast, lungs infected with pneumonia often show opacities or white patches, indicating fluid or inflammation. Pneumonia can also cause reduced lung expansion and increased density in affected areas.

# %% [markdown]
# -----------------------

# %% [markdown]
# **Imbalanced data:**
# Checking for the count of normal x-rays and x-rays with pneumonia in the training folder.

# %%
#checking the count of both values
len(pneumonia_files), len(normal_files)
# Out:
# (3875, 1341)

# %% [markdown]
# * Out of the **100%** (5,216) training images available, **74%** (3,875) of them are Pneumonia images and **26%** (1,341) of them are Normal Lung images. This demonstrates class imbalance. Find a graph below. \
# * In an ideally balanced dataset, each class would have approximately around, but not exactly 50% for each class to work with a binary classification problem. \

# %%
#plotting the count of pneumonia and normal class
# create a variable with the counts:
pneumonia_count = len(pneumonia_files)
normal_count = len(normal_files)

#define the labels and their corresponding counts
labels = ['Pneumonia', 'Normal']
counts = [pneumonia_count, normal_count]

#plot
plt.figure(figsize=(5, 5))
plt.bar(labels, counts) #labels on the x-axis and counts on the y-axis
plt.ylabel('Count')
plt.title('Class Imbalance in Training Folder')
plt.show()

# %% [markdown]
# **Data Augmentation:** Due to the significant class imbalance in the training dataset, I will use the **ImageDataGenerator** to generate synthetic images. This approach will help balance the classes and reduce the risk of overfitting by augmenting the dataset with varied versions of the existing images.

# %%
#setting parameters
img_size=(100,100)
SHAPE=(100,100,3)
batch_size=32

# %%
#setting the data generator for the train and validation datasets
datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
                             rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             shear_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=False,
                             fill_mode='nearest')

#setting the test data generator
test_datagen=ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
#applying the data generator to training and validation sets
train_set=datagen.flow_from_directory(train_dir,
                                      class_mode='binary',
                                      target_size=img_size,
                                      batch_size=batch_size,
                                      #shuffle=False,
                                      seed=42)

val_set=datagen.flow_from_directory(val_dir,
                                      class_mode='binary',
                                      target_size=img_size,
                                      batch_size=batch_size,
                                      shuffle=False,
                                      seed=42)
test_set=test_datagen.flow_from_directory(test_dir,
                                      class_mode='binary',
                                      target_size=img_size,
                                      batch_size=batch_size,
                                      shuffle=False,
                                      seed=42)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# Now that the directories will be going through **ImageDataGenerator** their names (train_dir, val_dir, test_dir) will change to: train_set, val_set and test_set.

# %% [markdown]
# # Modeling:

# %% [markdown]
# **Model building** is an iterative process that begins with developing a baseline model, which serves as a reference point for comparison. Each subsequent model iteration will be designed with clear justifications based on the performance of previous models. \
# - By systematically refining and evaluating these iterations, the goal is to identify the model that delivers the best performance for this binary classification task.

# %% [markdown]
# ## Baseline model:

# %% [markdown]
# This **baseline model** is a simple convolutional neural network (CNN) designed for binary classification. \
# It consists of a convolutional layer with 32 filters, a 3x3 kernel, ReLU activation, and max-pooling to reduce spatial dimensions. The feature maps are then flattened and passed through a fully connected layer with 128 neurons and ReLU activation. Finally, a single output neuron with a sigmoid activation is used to predict the binary class.

# %%
#setting up the baseline model
base_model = models.Sequential([

    #first convolutional layer
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu', input_shape=(100,100, 3)),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),

    #flatten the feature maps
    layers.Flatten(),

    #fully connected layer
    layers.Dense(128, activation='relu'),

    #output layer with a single neuron for binary classification
    layers.Dense(1, activation='sigmoid')])

# %%
#setting metrics for all the models to be trained
METRICS=['accuracy',
         tf.keras.metrics.Precision(name='precision'),
         tf.keras.metrics.Recall(name='recall')]

# %%
#compile the model
base_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=METRICS)

# %% [markdown]
# **Early Stopping:** prevents overfitting and saves resources by halting training when the model's performance no longer improves, reducing unnecessary computations.

# %%
#define EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss',  #monitor validation loss
    patience=5,          #number of epochs with no improvement before stopping
    restore_best_weights=True  #restore weights from the epoch with the best validation loss
)
#learning rate scheduler callback
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

# %%
base_model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_28 (Conv2D)                   │ (None, 98, 98, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_28 (MaxPooling2D)      │ (None, 49, 49, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_8 (Flatten)                  │ (None, 153664)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 128)                 │      19,669,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_30 (Dense)                     │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 19,671,041 (75.04 MB)
#  Trainable params: 19,671,041 (75.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#calculates # of batches needed to cover the training set in one epoch
steps_per_epoch = math.ceil(train_set.samples / batch_size)

#calculates # of batches needed to cover the validation set
validation_steps = val_set.samples // batch_size

# %%
base_model_hist = base_model.fit(
    train_set,
    epochs=10,  # Set the maximum number of epochs
    validation_data=val_set,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.7117 - loss: 184.3078 - precision: 0.8351 - recall: 0.8341 - val_accuracy: 0.5625 - val_loss: 26.4053 - val_precision: 0.5333 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 2/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - accuracy: 0.8483 - loss: 4.5787 - precision: 0.8970 - recall: 0.9007 - val_accuracy: 0.8125 - val_loss: 2.2386 - val_precision: 0.7273 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 3/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - accuracy: 0.8392 - loss: 4.9028 - precision: 0.8930 - recall: 0.8898 - val_accuracy: 0.7500 - val_loss: 7.3335 - val_precision: 0.7000 - val_recall: 0.8750 - learning_rate: 0.0010
# Epoch 4/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.8631 - loss: 3.1358 - precision: 0.9099 - recall: 0.9069 - val_accuracy: 0.8125 - val_loss: 6.0426 - val_precision: 0.7273 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 5/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8746 - loss: 2.3503 - precision: 0.9133 - recall: 0.9196
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.8746 - loss: 2.3503 - precision: 0.9133 - recall: 0.9196 - val_accuracy: 0.6875 - val_loss: 5.5647 - val_precision: 0.6154 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 6/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.8705 - loss: 1.8961 - precision: 0.9069 - recall: 0.9177 - val_accuracy: 0.9375 - val_loss: 0.8079 - val_precision: 0.8889 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 7/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.8920 - loss: 1.2562 - precision: 0.9304 - recall: 0.9261 - val_accuracy: 0.6250 - val_loss: 3.2029 - val_precision: 0.5714 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 8/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.8892 - loss: 1.0671 - precision: 0.9289 - recall: 0.9208 - val_accuracy: 0.6250 - val_loss: 3.4319 - val_precision: 0.5833 - val_recall: 0.8750 - learning_rate: 5.0000e-04
# Epoch 9/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - accuracy: 0.8842 - loss: 1.1317 - precision: 0.9231 - recall: 0.9207
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 166s 998ms/step - accuracy: 0.8842 - loss: 1.1315 - precision: 0.9231 - recall: 0.9207 - val_accuracy: 0.6875 - val_loss: 2.4394 - val_precision: 0.6364 - val_recall: 0.8750 - learning_rate: 5.0000e-04
# Epoch 10/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.8893 - loss: 0.8699 - precision: 0.9246 - recall: 0.9251 - val_accuracy: 0.6875 - val_loss: 2.0969 - val_precision: 0.6154 - val_recall: 1.0000 - learning_rate: 2.5000e-04

# %%
_#evaluate base model
results_base_train=base_model.evaluate(test_set)
results_base_train
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 314ms/step - accuracy: 0.7665 - loss: 6.3700 - precision: 0.4437 - recall: 0.6163
# [4.525392532348633, 0.8333333134651184, 0.824999988079071, 0.9307692050933838]

# %%
#unpacking values
basetest_loss, basetest_accuracy, basetest_precision, basetest_recall = results_base_train

# Calculate the F1 score
if basetest_precision + basetest_recall > 0:
    basetest_f1_score = 2 * (basetest_precision * basetest_recall) / (basetest_precision + basetest_recall)
else:
    basetest_f1_score = 0  # Handle the case where both precision and recall are zero to avoid division by zero

#print the result values
print(f"Test accuracy: {basetest_accuracy:.2f}")
print(f"Test precision: {basetest_precision:.2f}")
print(f"Test recall: {basetest_recall:.2f}")
print(f"F-1Score: {basetest_f1_score:.2f}")
# Out:
# Test accuracy: 0.83
# Test precision: 0.82
# Test recall: 0.93
# F-1Score: 0.87

# %% [markdown]
# ## Model 1:

# %% [markdown]
# Model 1 is more complex, having two convolutional layers and it starts with 32 filters in the first layer and increases to 64 in the second layer.

# %%
#test 1 model
test1_model= models.Sequential([

    #first convolutional layer
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(100,100, 3)),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),

    #second convolutional layer
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),

    #flatten the feature maps
    layers.Flatten(),

    #fully connected layer
    layers.Dense(128, activation='relu'),

    #output layer with a single neuron for binary classification
    layers.Dense(1, activation='sigmoid')])

# %%
#compile the model
test1_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=METRICS)

# %%
test1_history = test1_model.fit(
    train_set,
    epochs=10,
    validation_data=val_set,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 133s 781ms/step - accuracy: 0.6903 - loss: 17.0522 - precision: 0.7882 - recall: 0.8591 - val_accuracy: 0.4375 - val_loss: 0.9945 - val_precision: 0.4667 - val_recall: 0.8750 - learning_rate: 0.0010
# Epoch 2/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 138s 761ms/step - accuracy: 0.8413 - loss: 0.3735 - precision: 0.8925 - recall: 0.8944 - val_accuracy: 0.6875 - val_loss: 0.7679 - val_precision: 0.6364 - val_recall: 0.8750 - learning_rate: 0.0010
# Epoch 3/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 130s 782ms/step - accuracy: 0.8731 - loss: 0.3202 - precision: 0.9213 - recall: 0.9055 - val_accuracy: 0.5625 - val_loss: 1.8913 - val_precision: 0.5333 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 4/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 129s 775ms/step - accuracy: 0.8771 - loss: 0.3042 - precision: 0.9201 - recall: 0.9109 - val_accuracy: 0.6250 - val_loss: 2.1896 - val_precision: 0.5714 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 5/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 779ms/step - accuracy: 0.8866 - loss: 0.2628 - precision: 0.9233 - recall: 0.9275
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 143s 782ms/step - accuracy: 0.8866 - loss: 0.2628 - precision: 0.9234 - recall: 0.9275 - val_accuracy: 0.6250 - val_loss: 1.0194 - val_precision: 0.5714 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 6/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 141s 769ms/step - accuracy: 0.9027 - loss: 0.2408 - precision: 0.9425 - recall: 0.9240 - val_accuracy: 0.5625 - val_loss: 1.5257 - val_precision: 0.5385 - val_recall: 0.8750 - learning_rate: 5.0000e-04
# Epoch 7/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 143s 782ms/step - accuracy: 0.9124 - loss: 0.2061 - precision: 0.9500 - recall: 0.9317 - val_accuracy: 0.5625 - val_loss: 1.4251 - val_precision: 0.5333 - val_recall: 1.0000 - learning_rate: 5.0000e-04

# %%
#Evaluating the results of the model 1 with testing data
test1_results= test1_model.evaluate(test_set)
print("Evaluation results:", test1_results)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 0.8470 - loss: 0.4461 - precision: 0.5166 - recall: 0.5744
# Evaluation results: [0.368375301361084, 0.8493589758872986, 0.897849440574646, 0.8564102649688721]

# %%
#unpack and print the metrics obtained from model 1
test1_loss, test1_accuracy, test1_precision, test1_recall = test1_results
# Calculate the F1 score
if test1_precision + test1_recall > 0:
    test1_f1_score = 2 * (test1_precision * test1_recall) / (test1_precision + test1_recall)
else:
    test1_f1_score = 0  # Handle the case where both precision and recall are zero to avoid division by zero


print(f"Test accuracy: {test1_accuracy:.2f}")
print(f"Test precision: {test1_precision:.2f}")
print(f"Test recall: {test1_recall:.2f}")
print(f"F-1 Score: {test1_f1_score:.2f}")
# Out:
# Test accuracy: 0.85
# Test precision: 0.90
# Test recall: 0.86
# F-1 Score: 0.88

# %% [markdown]
# After training Model 1, the evaluation metrics indicate strong overall performance. The model achieved a test accuracy of 0.85, a test precision of 0.90 and a good recall of 0.86, the model demonstrates a strong ability to identify pneumonia cases while minimizing false negatives, which is critical for this application.

# %%
# Plot training and validation precision
plt.plot(test1_history.history['precision'], label='Training Precision')
plt.plot(test1_history.history['val_precision'], label='Validation Precision')

# Plot training and validation accuracy
plt.plot(test1_history.history['accuracy'], label='Training Accuracy')
plt.plot(test1_history.history['val_accuracy'], label='Validation Accuracy')

# Plot training and validation recall
plt.plot(test1_history.history['recall'], label='Training Recall')
plt.plot(test1_history.history['val_recall'], label='Validation Recall')

# Add labels and title
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.title('Precision, Accuracy, and Recall over Epochs (Model 1)')
plt.legend()
plt.show()

# %% [markdown]
# ## Model 2:

# %%
#setting up model 2
test2_model = models.Sequential([
    #first convolutional layer
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    layers.MaxPooling2D((2, 2)),

    #second convolutional layer
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    #third conv layer
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    #fourth conv layer
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(), #flatten layer

    #fully connected Dense layer with 512 neurons
    #layers.Dense(512, activation='relu'),
    #layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.1), #10% of neurons will be dropped
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.2), #20% of neurons will be dropped
    #Increasing the dropout rate can provide stronger regularization

    #batch normalization maintains a stable distribution of activations throughout the network
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.2),
    layers.BatchNormalization(),

    #output layer: dense layer with 2 layers
    layers.Dense(1, activation='sigmoid')  #for binary classification
])

# %%
#compile for model 2
test2_model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=METRICS)

# %%
#print summary model 2 of architecture
test2_model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_31 (Conv2D)                   │ (None, 98, 98, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_31 (MaxPooling2D)      │ (None, 49, 49, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_32 (Conv2D)                   │ (None, 47, 47, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_32 (MaxPooling2D)      │ (None, 23, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_33 (Conv2D)                   │ (None, 21, 21, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_33 (MaxPooling2D)      │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_34 (Conv2D)                   │ (None, 8, 8, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_34 (MaxPooling2D)      │ (None, 4, 4, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_10 (Flatten)                 │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_33 (Dense)                     │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_18 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_34               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_34 (Dense)                     │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_19 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_35               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_35 (Dense)                     │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_20 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_36               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_36 (Dense)                     │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,150,017 (4.39 MB)
#  Trainable params: 1,146,945 (4.38 MB)
#  Non-trainable params: 3,072 (12.00 KB)

# %%
test2_history = test2_model.fit(
    train_set,
    epochs=10,
    validation_data=val_set,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 150s 876ms/step - accuracy: 0.7552 - loss: 0.5583 - precision: 0.8890 - recall: 0.8021 - val_accuracy: 0.5000 - val_loss: 1.6223 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 2/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 194s 827ms/step - accuracy: 0.8599 - loss: 0.3340 - precision: 0.9018 - recall: 0.9096 - val_accuracy: 0.5000 - val_loss: 6.9688 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 3/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 143s 826ms/step - accuracy: 0.8734 - loss: 0.3042 - precision: 0.9125 - recall: 0.9212 - val_accuracy: 0.5625 - val_loss: 1.3904 - val_precision: 0.5333 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 4/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 162s 979ms/step - accuracy: 0.8863 - loss: 0.2771 - precision: 0.9277 - recall: 0.9189 - val_accuracy: 0.5000 - val_loss: 1.3271 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 5/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 145s 857ms/step - accuracy: 0.8933 - loss: 0.2598 - precision: 0.9262 - recall: 0.9297 - val_accuracy: 0.5000 - val_loss: 2.2159 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 0.0010

# %%
#evaluate and print the results of model 2
test2_results= test2_model.evaluate(test_set)
print("Evaluation results:", test2_results)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 336ms/step - accuracy: 0.4944 - loss: 0.9710 - precision: 0.3378 - recall: 0.6636
# Evaluation results: [0.5812590718269348, 0.7115384340286255, 0.685512363910675, 0.9948717951774597]

# %%
#unpack and print the metrics obtained from model 2
test2_loss, test2_accuracy, test2_precision, test2_recall = test2_results

# Calculate the F1 score
if test2_precision + test2_recall > 0:
    test2_f1_score = 2 * (test2_precision * test2_recall) / (test2_precision + test2_recall)
else:
    test2_f1_score = 0  # Handle the case where both precision and recall are zero to avoid division by zero


print(f"Test accuracy: {test2_accuracy:.2f}")
print(f"Test precision: {test2_precision:.2f}")
print(f"Test recall: {test2_recall:.2f}")
print(f"Test F1 Score: {test2_f1_score:.2f}")
# Out:
# Test accuracy: 0.71
# Test precision: 0.69
# Test recall: 0.99
# Test F1 Score: 0.81

# %% [markdown]
# Model 2 achieved a test accuracy of 0.71, with a precision of 0.69 and a recall of 0.99, indicating it is highly effective at identifying positive cases. The F1 score is 0.81, reflecting a good balance between precision and recall.

# %%
# Plot training and validation precision
plt.plot(test2_history.history['precision'], label='Training Precision')
plt.plot(test2_history.history['val_precision'], label='Validation Precision')

# Plot training and validation accuracy
plt.plot(test2_history.history['accuracy'], label='Training Accuracy')
plt.plot(test2_history.history['val_accuracy'], label='Validation Accuracy')

# Plot training and validation recall
plt.plot(test2_history.history['recall'], label='Training Recall')
plt.plot(test2_history.history['val_recall'], label='Validation Recall')

# Add labels and title
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.title('Precision, Accuracy, and Recall over Epochs (Model 2)')
plt.legend()
plt.show()

# %% [markdown]
# ## Model 3:

# %% [markdown]
# **Model 3** improves on model 2 with L2 regularization to reduce overfitting, an additional convolutional layer with 128 filters for better feature extraction, and adjusted dropout rates (30-40%) for stronger regularization. Batch normalization is applied after each layer, and a learning rate scheduler adapts the rate if validation loss plateaus, leading to more efficient training.

# %%
#setting up model 3 with new tuning
test3_model = models.Sequential([
    #first convolutional layer
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3),
                  kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),

    #second convolutional layer
    layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),

    #third convolutional layer
    layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),

    #fourth convolutional layer
    layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),

    layers.Flatten(),  # Flatten layer

    #fully connected dense layers with Dropout and Batch Normalization
    layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.3),
    layers.BatchNormalization(),

    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.4),
    layers.BatchNormalization(),

    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.4),
    layers.BatchNormalization(),

    #output layer: dense layer with 1 output neuron for binary classification
    layers.Dense(1, activation='sigmoid')
])

# %%
#compile the model
test3_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=METRICS
)

# %%
#print summary for model 3 of architecture
test3_model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_15 (Conv2D)                   │ (None, 98, 98, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_15 (MaxPooling2D)      │ (None, 49, 49, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_16 (Conv2D)                   │ (None, 47, 47, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_16 (MaxPooling2D)      │ (None, 23, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 21, 21, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_17 (MaxPooling2D)      │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 8, 8, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_18 (MaxPooling2D)      │ (None, 4, 4, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 2, 2, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_19 (MaxPooling2D)      │ (None, 1, 1, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 512)                 │          33,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_17               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_18               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_19               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 958,081 (3.65 MB)
#  Trainable params: 955,009 (3.64 MB)
#  Non-trainable params: 3,072 (12.00 KB)

# %%
#fit the model with EarlyStopping and ReduceLROnPlateau
test3_history = test3_model.fit(
    train_set,
    epochs=10,
    validation_data=val_set,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 165s 951ms/step - accuracy: 0.7552 - loss: 2.1214 - precision: 0.8965 - recall: 0.7669 - val_accuracy: 0.5000 - val_loss: 2.8695 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 2/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 160s 963ms/step - accuracy: 0.8886 - loss: 1.6651 - precision: 0.9267 - recall: 0.9245 - val_accuracy: 0.5625 - val_loss: 2.2907 - val_precision: 0.5333 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 3/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 949ms/step - accuracy: 0.9031 - loss: 1.3309 - precision: 0.9346 - recall: 0.9351 - val_accuracy: 0.5625 - val_loss: 2.5205 - val_precision: 0.5333 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 4/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 202s 948ms/step - accuracy: 0.9042 - loss: 1.0954 - precision: 0.9286 - recall: 0.9423 - val_accuracy: 0.5000 - val_loss: 1.8345 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 5/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 155s 936ms/step - accuracy: 0.9281 - loss: 0.8642 - precision: 0.9521 - recall: 0.9514 - val_accuracy: 0.5000 - val_loss: 3.1298 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 0.0010

# %%
#evaluate and print the results of model 3
test3_results= test3_model.evaluate(test_set)
print("Evaluation results:", test3_results)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 342ms/step - accuracy: 0.8309 - loss: 1.8494 - precision: 0.4842 - recall: 0.6264
# Evaluation results: [1.7721927165985107, 0.870192289352417, 0.8669833540916443, 0.9358974099159241]

# %%
#unpack and print the metrics obtained from model 3
test3_loss, test3_accuracy, test3_precision, test3_recall = test3_results

# Calculate the F1 score
if test3_precision + test3_recall > 0:
    test3_f1_score = 2 * (test3_precision * test3_recall) / (test3_precision + test3_recall)
else:
    test3_f1_score = 0  # Handle the case where both precision and recall are zero to avoid division by zero


print(f"Test accuracy: {test3_accuracy:.2f}")
print(f"Test precision: {test3_precision:.2f}")
print(f"Test recall: {test3_recall:.2f}")
print(f"Test F1 Score: {test3_f1_score:.2f}")
# Out:
# Test accuracy: 0.87
# Test precision: 0.87
# Test recall: 0.94
# Test F1 Score: 0.90

# %%
# Plot training and validation precision
plt.plot(test3_history.history['precision'], label='Training Precision')
plt.plot(test3_history.history['val_precision'], label='Validation Precision')

# Plot training and validation accuracy
plt.plot(test3_history.history['accuracy'], label='Training Accuracy')
plt.plot(test3_history.history['val_accuracy'], label='Validation Accuracy')

# Plot training and validation recall
plt.plot(test3_history.history['recall'], label='Training Recall')
plt.plot(test3_history.history['val_recall'], label='Validation Recall')

# Add labels and title
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.title('Precision, Accuracy, and Recall over Epochs (Model 3)')
plt.legend()
plt.show()

# %% [markdown]
# **Comparing scores of Model 1, 2 and 3:**
# - Model 1 has the highest precision, meaning fewer false positives.
# - Model 2 has the highest recall (minimizing false negatives), but it is less balanced in other metrics.
# - Model 3 has the highest F1 score, balancing precision and recall.
#
# **Conclusion:** Model 3 is the best choice. It has strong recall (0.94), a good F1 score (0.90), and solid accuracy and precision. It will now be evaluated for one last time without callbacks.

# %% [markdown]
# # Evaluation:

# %% [markdown]
# Performing a final evaluation of Model 3, training the model fully without interruption to thoroughly assess its perrformace. This step is critical for making an informed final decision on the recommended model, particularly given the importance of high recall and balanced performance for detecting pneumonia accurately and reliably.

# %% [markdown]
# ## Evaluation of Model 3:

# %% [markdown]
# Running model 3 one last time, but without callbacks.

# %%
#fit the model without EarlyStopping and ReduceLROnPlateau
test3_history = test3_model.fit(
    train_set,
    epochs=10,
    validation_data=val_set #removed callbacks
)
# Out:
# Epoch 1/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.8762 - loss: 1.6472 - precision: 0.9168 - recall: 0.9154 - val_accuracy: 0.6250 - val_loss: 1.9803 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 2/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 174s 971ms/step - accuracy: 0.9003 - loss: 1.2030 - precision: 0.9278 - recall: 0.9406 - val_accuracy: 0.6250 - val_loss: 1.5068 - val_precision: 0.6000 - val_recall: 0.7500
# Epoch 3/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 945ms/step - accuracy: 0.9170 - loss: 0.9011 - precision: 0.9444 - recall: 0.9449 - val_accuracy: 0.5000 - val_loss: 2.8334 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 4/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 947ms/step - accuracy: 0.9127 - loss: 0.7381 - precision: 0.9408 - recall: 0.9425 - val_accuracy: 0.6250 - val_loss: 1.4943 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 5/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 200s 936ms/step - accuracy: 0.9167 - loss: 0.6326 - precision: 0.9401 - recall: 0.9490 - val_accuracy: 0.6250 - val_loss: 1.0181 - val_precision: 0.7500 - val_recall: 0.3750
# Epoch 6/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 202s 937ms/step - accuracy: 0.9144 - loss: 0.5427 - precision: 0.9417 - recall: 0.9444 - val_accuracy: 0.6250 - val_loss: 1.1253 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 7/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 204s 948ms/step - accuracy: 0.9346 - loss: 0.4396 - precision: 0.9566 - recall: 0.9556 - val_accuracy: 0.5000 - val_loss: 4.0231 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 8/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 200s 928ms/step - accuracy: 0.9236 - loss: 0.4166 - precision: 0.9500 - recall: 0.9463 - val_accuracy: 0.5625 - val_loss: 1.4601 - val_precision: 1.0000 - val_recall: 0.1250
# Epoch 9/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 202s 931ms/step - accuracy: 0.9231 - loss: 0.3931 - precision: 0.9444 - recall: 0.9517 - val_accuracy: 0.5625 - val_loss: 2.4161 - val_precision: 1.0000 - val_recall: 0.1250
# Epoch 10/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 202s 935ms/step - accuracy: 0.9239 - loss: 0.3752 - precision: 0.9494 - recall: 0.9481 - val_accuracy: 0.7500 - val_loss: 0.7543 - val_precision: 0.7500 - val_recall: 0.7500

# %%
#evaluate and print the results of model 3
test3_results= test3_model.evaluate(test_set)
print("Evaluation results:", test3_results)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 387ms/step - accuracy: 0.8408 - loss: 0.5508 - precision: 0.5036 - recall: 0.5981
# Evaluation results: [0.5078895092010498, 0.8573718070983887, 0.8849104642868042, 0.8871794939041138]

# %%
#unpack and print the metrics obtained from model 3
test3_loss, test3_accuracy, test3_precision, test3_recall = test3_results

# Calculate the F1 score
if test3_precision + test3_recall > 0:
    test3_f1_score = 2 * (test3_precision * test3_recall) / (test3_precision + test3_recall)
else:
    test3_f1_score = 0  # Handle the case where both precision and recall are zero to avoid division by zero


print(f"Test accuracy: {test3_accuracy:.2f}")
print(f"Test precision: {test3_precision:.2f}")
print(f"Test recall: {test3_recall:.2f}")
print(f"Test F1 Score: {test3_f1_score:.2f}")
# Out:
# Test accuracy: 0.86
# Test precision: 0.88
# Test recall: 0.89
# Test F1 Score: 0.89

# %% [markdown]
# ### Evaluation of Final Model Performance:
# - **Test Accuracy**: **0.86** – Indicates the overall percentage of correct predictions. While useful, it does not fully capture class-specific performance, especially in imbalanced datasets.
# - **Test Precision**: **0.88** – Reflects the model's ability to avoid false positives, ensuring fewer healthy cases are misclassified as pneumonia. This is crucial for avoiding unnecessary stress and further medical tests for healthy patients.
# - **Test Recall**: **0.89** – Measures the model’s ability to identify true pneumonia cases, minimizing false negatives. This is critical, as missed pneumonia diagnoses could lead to severe health consequences or even fatal outcomes.
# - **Test F1 Score**: **0.89** – Balances precision and recall, making it an essential metric for this task since both false positives and false negatives carry significant consequences.
#
# ### Justification for Metrics:
# 1. **Recall**: The primary focus due to the severe consequences of missing a pneumonia diagnosis (false negatives). Ensures most patients who require treatment are identified.
# 2. **Precision**: Important to avoid overwhelming healthcare systems with false alarms (false positives), reducing unnecessary interventions for healthy patients.
# 3. **F1 Score**: Provides a balanced view when precision and recall need to be equally weighted for overall performance evaluation.
#
# ### Runtime:
# The model’s runtime of **31 minutes** for evaluation is reasonable given the complexity of the problem and the high recall achieved, ensuring the model remains practical for real-world application.

# %% [markdown]
# ### Classification Report:

# %%
def get_class_report(test3_model, test_set, threshold=0.5):
    y_pred_probs = test3_model.predict(test_set)
    y_true = test_set.classes

    #convert probabilities to binary predictions based on the threshold
    threshold = 0.5
    y_pred_binary = (y_pred_probs >= threshold).astype(int)

    report = classification_report(y_true, y_pred_binary, target_names=['Normal (Class 0)','Pneumonia (Class 1)'])
    print(report)
print('Model 3 Classification Report:')
get_class_report(test3_model, test_set)
# Out:
# Model 3 Classification Report:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 456ms/step
#                      precision    recall  f1-score   support
#
#    Normal (Class 0)       0.81      0.81      0.81       234
# Pneumonia (Class 1)       0.88      0.89      0.89       390
#
#            accuracy                           0.86       624
#           macro avg       0.85      0.85      0.85       624
#        weighted avg       0.86      0.86      0.86       624

# %% [markdown]
# ### Confusion Matrix:

# %%
# Confusion Matrix
y_true = test_set.classes
y_pred_probs = test3_model.predict(test_set)
threshold = 0.5
y_pred_binary = (y_pred_probs >= threshold).astype(int)

acc = accuracy_score(y_true, y_pred_binary) * 100
cm = confusion_matrix(y_true, np.round(y_pred_binary))
tn, fp, fn, tp = cm.ravel()
# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred_binary)
cm = pd.DataFrame(cm, index=['0', '1'], columns=['0', '1'])
plt.figure(figsize=(6, 6))
sns.heatmap(cm, cmap="Blues", annot=True, fmt='', xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.show()
print(f"Accuracy: {acc:.2f}%")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 402ms/step
# Accuracy: 85.74%

# %% [markdown]
# ### Consequences of Errors:
# - **False Negatives**: Could delay treatment, potentially worsening patient outcomes or risking fatalities.
# - **False Positives**: May lead to unnecessary stress, additional tests, and wasted resources but are less critical than false negatives.
#
# Overall, the final model demonstrates strong performance, particularly in recall, aligning well with the project’s goal of minimizing missed pneumonia diagnosis while maintaining a balance between precision and recall.

# %% [markdown]
# # Summary:

# %% [markdown]
# This project focused on developing a **binary image classifier** to detect pneumonia from chest X-rays. The goal is to assist doctors in faster diagnosis and serve as a second opinion in clinical decision-making. The model prioritizes high recall to minimize false negatives, ensuring patient safety while balancing precision to avoid unnecessary interventions.

# %% [markdown]
# ## Results:

# %% [markdown]
# ### Model Results
# - **Model 1**:
#   - Runtime approximately 16 minutes. 7 out of 10 epochs.
#   - Accuracy: 0.85, Precision: 0.90, Recall: 0.86, F1 Score: 0.88
#   - Strong precision but lower recall, leading to more missed pneumonia cases.
#
# - **Model 2**:
#   - Runtime approximately 13 minutes. 5 out of 10 epochs.
#   - Accuracy: 0.71, Precision: 0.69, Recall: 0.99, F1 Score: 0.81
#   - High recall but poor balance due to low precision and accuracy.
#
# - **Model 3**:
#   - Runtime approximately 23 minutes. 5 out of 10 epochs.
#   - Accuracy: 0.87, Precision: 0.87, Recall: 0.94, F1 Score: 0.90
#   - Best balance between recall and precision, making it the top-performing model.
#
# ### Final Model (No Callbacks):
# - Runtime 31 minutes. 10 out of 10 epochs.
# - Accuracy: 0.86, Precision: 0.88, Recall: 0.89, F1 Score: 0.89
# - Maintained high recall while balancing precision and overall performance, with reasonable runtime (31 minutes). This model is well-suited for deployment in real-world clinical applications.
